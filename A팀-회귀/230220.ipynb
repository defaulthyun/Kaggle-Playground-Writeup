# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler, RobustScaler, Normalizer
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.metrics import cohen_kappa_score, confusion_matrix,ConfusionMatrixDisplay
from xgboost import XGBRegressor

# !pip install pgeocode

# import pgeocode

# %%
import xgboost
xgboost.__version__
# Out:
# '0.90'

# %%
path = '/content/drive/MyDrive/모듈프젝2/A팀-회귀/data/playground-series-season-3-episode-6/'

train = pd.read_csv(path + 'train.csv', dtype={'cityCode': object})
test = pd.read_csv(path + 'test.csv', dtype={'cityCode': object})
original = pd.read_csv(path + 'ParisHousing.csv', dtype={'cityCode': object})

original = original.reset_index()
original['id'] = original['index'] + 1000000
original = original.drop(columns = ['index'])
train.head()
# Out:
#    id  squareMeters  numberOfRooms  hasYard  hasPool  floors cityCode  \
# 0   0         34291             24        1        0      47    35693
# 1   1         95145             60        0        1      60    34773
# 2   2         92661             45        1        1      62    45457
# 3   3         97184             99        0        0      59    15113
# 4   4         61752            100        0        0      57    64245
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              2              1  2000           0                  1
# 1              1              4  2000           0                  1
# 2              4              8  2020           1                  1
# 3              1              1  2000           0                  1
# 4              8              4  2018           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0         8   5196     369               0             3  3436795.2
# 1       729   4496     277               0             6  9519958.0
# 2      7473   8953     245               1             9  9276448.1
# 3      6424   8522     256               1             9  9725732.2
# 4      7151   2786     863               0             7  6181908.8

# %%
original.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors cityCode  \
# 0         75523              3        0        1      63     9373
# 1         80771             39        1        1      98    39381
# 2         55712             58        0        1      19    34457
# 3         32316             47        0        0       6    27939
# 4         70429             19        1        1      90    38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price       id
# 0      4313   9005     956               0             7  7559081.5  1000000
# 1      3653   2436     128               1             2  8085989.5  1000001
# 2      2937   8852     135               1             9  5574642.1  1000002
# 3       659   7141     359               0             3  3232561.2  1000003
# 4      8435   2429     292               1             4  7055052.0  1000004

# %%
train['cityCode'] = train['cityCode'].str.zfill(5)
test['cityCode'] = test['cityCode'].str.zfill(5)
original['cityCode'] = original['cityCode'].str.zfill(5)

# %%
print(len(train))
print(len(test))
print(len(original))
# Out:
# 22730
# 15154
# 10000

# %%
num_cols = train.select_dtypes(include=np.number).columns.tolist()
num_cols.remove('id')
num_cols.remove('price')
num_cols
# Out:
# ['squareMeters',
#  'numberOfRooms',
#  'hasYard',
#  'hasPool',
#  'floors',
#  'cityPartRange',
#  'numPrevOwners',
#  'made',
#  'isNewBuilt',
#  'hasStormProtector',
#  'basement',
#  'attic',
#  'garage',
#  'hasStorageRoom',
#  'hasGuestRoom']

# %%
ncols = 3
nrows = int(np.ceil(len(num_cols)/ncols))
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 15))
for ax, f in zip(axes.flat, num_cols):
    sns.kdeplot(train[f], color='r', label='train', ax=ax)
    sns.kdeplot(test[f], color='b', label='test', ax=ax)
    sns.kdeplot(original[f], color='g', label='original', ax=ax)
    ax.set_title(f)
    ax.legend()
plt.tight_layout()
plt.show()

# %%
# eiffel_zip = '75007'
# dist = pgeocode.GeoDistance('fr')
# train['Dist_From_Eiffel'] = train['cityCode'].apply(lambda x: dist.query_postal_code(eiffel_zip , x))

# nomi = pgeocode.Nominatim('fr')
# cols = ['place_name','state_name','state_code','latitude','longitude']

# train[cols] = train.apply(lambda row: nomi.query_postal_code(row['cityCode'])[cols], axis=1, result_type='expand')
# train.head()

# original[cols] = original.apply(lambda row: nomi.query_postal_code(row['cityCode'])[cols], axis=1, result_type='expand')
# original.head()

# %%
corr_cols = num_cols + ['price']
plt.figure(figsize=(15,15))
sns.heatmap(train[corr_cols].corr(),annot=True)
# plt.savefig("Heatmap.png")
plt.show()

# %%
made = pd.DataFrame(train.groupby(['made']).size()).reset_index().rename(columns = {0:'Count'})
made = made[made['made']< 2022]

made1 = pd.DataFrame(train.groupby(['made'])['price'].mean()).reset_index().rename(columns = {0:'mean_price'})

made = pd.merge(made,made1, on = 'made', how = 'inner')

ax = made.plot(x="made", y="Count", legend=False)
ax2 = ax.twinx()
made.plot(x="made", y="price", ax=ax2, legend=False, color="r")
ax.figure.legend()
plt.show()

# %%
made[made['made']<= 2000].corr()
# Out:
#            made     Count     price
# made   1.000000  0.672256 -0.790501
# Count  0.672256  1.000000 -0.486776
# price -0.790501 -0.486776  1.000000

# %%
made[made['made']> 2007].corr()
# Out:
#            made     Count     price
# made   1.000000  0.025725 -0.069582
# Count  0.025725  1.000000 -0.346971
# price -0.069582 -0.346971  1.000000

# %%
train = pd.concat([train,original])

# %%
test
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors cityCode  \
# 0      22730         47580             89        0        1       8    54830
# 1      22731         62083             38        0        0      87    08576
# 2      22732         90499             75        1        1      37    62454
# 3      22733         16354             47        1        1       9    09262
# 4      22734         67510              8        0        0      55    24112
# ...      ...           ...            ...      ...      ...     ...      ...
# 15149  37879         86184             74        1        1      73    14009
# 15150  37880         45885             41        1        1      64    84208
# 15151  37881         73554             51        0        0      41    49263
# 15152  37882         77604             51        0        1      33    67056
# 15153  37883         18179             50        1        0      41    50124
#
#        cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0                  5              3  1995           0                  0
# 1                 10              3  1994           1                  1
# 2                  9              6  1997           0                  1
# 3                  6              5  2019           1                  1
# 4                  3              7  2014           1                  1
# ...              ...            ...   ...         ...                ...
# 15149              2             10  1993           1                  0
# 15150              4              5  2008           0                  0
# 15151             10              5  2004           0                  1
# 15152              4              3  2019           0                  0
# 15153              2              2  2004           1                  0
#
#        basement  attic  garage  hasStorageRoom  hasGuestRoom
# 0          6885   8181     241               0             8
# 1          4601   9237     393               1             4
# 2          7454   2680     305               0             2
# 3           705   5097     122               1             5
# 4          3715   7979     401               1             9
# ...         ...    ...     ...             ...           ...
# 15149      3714   3894     665               1             1
# 15150       783   7628     976               0             0
# 15151      8207   1777     775               0            10
# 15152      9578   9706     135               0             2
# 15153      4163   9923     622               0             6
#
# [15154 rows x 17 columns]

# %%
# 범위 2015 추가
train_1 = train[train['made']<=2000]
test_1 = test[test['made']<=2000]
train_2 = train[(train['made']>=2001) & (train['made']<=2007)]
test_2 = test[(test['made']>=2001) & (test['made']<=2007)]
train_3 = train[(train['made']>=2008) & (train['made']<=2015)]
test_3 = test[(test['made']>=2008) & (test['made']<=2015)]
train_4 = train[train['made']>2015]
test_4 = test[test['made']>2015]

# %%
train_1 = pd.merge(train_1,made[['made','Count']], on = 'made', how = 'inner')
test_1 = pd.merge(test_1,made[['made','Count']], on = 'made', how = 'inner')
plt.figure(figsize=(15,15))
sns.heatmap(train_1.corr(),annot=True)
# plt.savefig("Heatmap.png")
plt.show()

# %%
train_2 = pd.merge(train_2,made[['made','Count']], on = 'made', how = 'inner')
test_2 = pd.merge(test_2,made[['made','Count']], on = 'made', how = 'inner')
plt.figure(figsize=(15,15))
sns.heatmap(train_2.corr(),annot=True)
# plt.savefig("Heatmap.png")
plt.show()

# %%
train_3 = pd.merge(train_3,made[['made','Count']], on = 'made', how = 'inner')
test_3 = pd.merge(test_3,made[['made','Count']], on = 'made', how = 'inner')
plt.figure(figsize=(15,15))
sns.heatmap(train_3.corr(),annot=True)
# plt.savefig("Heatmap.png")
plt.show()

# %%
train_4 = pd.merge(train_4,made[['made','Count']], on = 'made', how = 'inner')
test_4 = pd.merge(test_4,made[['made','Count']], on = 'made', how = 'inner')
plt.figure(figsize=(15,15))
sns.heatmap(train_4.corr(),annot=True)
# plt.savefig("Heatmap.png")
plt.show()

# %%
num_cols = num_cols + ['Count']

# %%
X1 = train_1[num_cols]
# X1 = train_1[['squareMeters']]
y1 = train_1['price']

model=XGBRegressor(max_depth=3, learning_rate=0.24 , n_estimators=3000, objective='reg:linear', booster='gbtree')
XGB=model.fit(X1,y1)


X_test = test_1[num_cols]
# X_test = test_1[['squareMeters']]
prediction=XGB.predict(X_test)

test_1['price'] = prediction
test_1
# Out:
# [01:37:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#          id  squareMeters  numberOfRooms  hasYard  hasPool  floors cityCode  \
# 0     22730         47580             89        0        1       8    35693
# 1     22751         69856             47        0        1      26    77004
# 2     22755         23608             51        0        0      31    84602
# 3     22775         67724             11        1        1      64    51336
# 4     22815         50778             39        0        1      94    49199
# ...     ...           ...            ...      ...      ...     ...      ...
# 5584  35303         84696             45        0        0      14    24522
# 5585  35522         42630             34        0        1      25    37363
# 5586  35686         18316             20        0        1       5    28086
# 5587  36267         41700             48        0        1       8    84704
# 5588  36808         42630             34        1        0      66    30127
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0                 5              3  1995           0                  0
# 1                 1              8  1995           1                  0
# 2                10              6  1995           1                  0
# 3                 2             10  1995           0                  1
# 4                 2              1  1995           0                  0
# ...             ...            ...   ...         ...                ...
# 5584              7              4  1991           0                  1
# 5585              9              7  1991           1                  0
# 5586              2              6  1991           0                  0
# 5587              5              7  1991           0                  0
# 5588              2              4  1991           0                  1
#
#       basement  attic  garage  hasStorageRoom  hasGuestRoom  Count       price
# 0         6885   8181     241               0             8    631  4758361.00
# 1           17    853     854               1             8    631  6996933.50
# 2         6410   8153     945               1             8    631  2366349.00
# 3         7448   1932     128               1             2    631  6779206.50
# 4         5294   7178     614               0             2    631  5079564.50
# ...        ...    ...     ...             ...           ...    ...         ...
# 5584      8681   5246     524               1             6     30  8468392.00
# 5585      7976    331     236               0             0     30  4239267.50
# 5586      6574   2166     127               1             5     30  1846599.75
# 5587       743   7716     194               1             2     30  4202701.00
# 5588      7466    331     377               0             3     30  4266149.50
#
# [5589 rows x 19 columns]

# %%
X2 = train_2[num_cols]
# X2 = train_2[['squareMeters']]
y2 = train_2['price']

model=XGBRegressor(max_depth=3, learning_rate=0.24 , n_estimators=3000, objective='reg:linear', booster='gbtree')
XGB=model.fit(X2,y2)

X_test = test_2[num_cols]
# X_test = test_2[['squareMeters']]
prediction=XGB.predict(X_test)

test_2['price'] = prediction
test_2
# Out:
# [01:37:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#          id  squareMeters  numberOfRooms  hasYard  hasPool  floors cityCode  \
# 0     22740         69567             38        0        0      11    54900
# 1     22776         15351             34        0        0      10    68109
# 2     22868          4198              6        1        0      80    38929
# 3     22887         62064             86        1        1      35    48037
# 4     22907         91618              4        0        0      36    74838
# ...     ...           ...            ...      ...      ...     ...      ...
# 3225  36015         73748             84        0        0      32    85082
# 3226  36030         90170             63        1        1      20    04081
# 3227  36156         41700              8        0        0      64    53916
# 3228  36298         55620             61        1        1      90    66390
# 3229  30642         67735             63        0        1       9    24641
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0                 8              3  2003           0                  1
# 1                 3              6  2003           0                  0
# 2                 3              8  2003           0                  0
# 3                 2              3  2003           1                  0
# 4                 8              3  2003           1                  1
# ...             ...            ...   ...         ...                ...
# 3225              5              2  2001           1                  1
# 3226              9              5  2001           1                  0
# 3227              7              9  2001           1                  0
# 3228              3              4  2001           1                  1
# 3229              4              7  2002           0                  1
#
#       basement  attic  garage  hasStorageRoom  hasGuestRoom  Count  \
# 0         8194   8627     124               0             3   1156
# 1         6341   5844     929               1             6   1156
# 2         3795   4194     885               1             8   1156
# 3         8000   2600     976               0            10   1156
# 4         6484   2731     121               1             5   1156
# ...        ...    ...     ...             ...           ...    ...
# 3225      4309   7379     273               1             9     59
# 3226      4196   2528     945               1             3     59
# 3227      8163   8153     194               0             8     59
# 3228      9867   7179     548               0             1     59
# 3229       823   8144     735               1             7      1
#
#             price
# 0     6967608.500
# 1     1543052.125
# 2      402396.625
# 3     6181293.500
# 4     9159930.000
# ...           ...
# 3225  7384625.500
# 3226  9012964.000
# 3227  4175313.750
# 3228  5567401.000
# 3229  6789238.500
#
# [3230 rows x 19 columns]

# %%
X3 = train_3[num_cols]
y3 = train_3['price']

model=XGBRegressor(max_depth=3, learning_rate=0.24 , n_estimators=3000, objective='reg:linear', booster='gbtree')
XGB=model.fit(X3,y3)

X_test = test_3[num_cols]
prediction=XGB.predict(X_test)

test_3['price'] = prediction
test_3
# Out:
# [01:37:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#          id  squareMeters  numberOfRooms  hasYard  hasPool  floors cityCode  \
# 0     22734         67510              8        0        0      55    64245
# 1     22739         98258             16        1        1      85    33928
# 2     22781         82202            100        0        0      80    61968
# 3     22813          8808              5        0        0      26    68015
# 4     22836         88828             54        0        0      64    06559
# ...     ...           ...            ...      ...      ...     ...      ...
# 3508  36857         54484             38        1        1      78    52734
# 3509  37118         54484             25        1        0      94    46686
# 3510  37278         27949             84        1        0      94    98846
# 3511  37431         76932             85        0        1      89    16768
# 3512  37775         41090              8        1        1       4    45597
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0                 3              7  2014           1                  1
# 1                 4              4  2014           0                  1
# 2                 9             10  2014           1                  1
# 3                 6              5  2014           0                  1
# 4                 5              9  2014           1                  1
# ...             ...            ...   ...         ...                ...
# 3508              8              6  2011           0                  1
# 3509              4              5  2011           0                  1
# 3510              5              9  2011           1                  1
# 3511              5              4  2011           0                  0
# 3512              4              9  2011           1                  1
#
#       basement  attic  garage  hasStorageRoom  hasGuestRoom  Count  \
# 0         3715   7979     401               1             9   1070
# 1         8253   1688     874               0             6   1070
# 2         6054   2486     516               0             2   1070
# 3         9885   3717     946               1             8   1070
# 4         7769   4514     513               0             7   1070
# ...        ...    ...     ...             ...           ...    ...
# 3508      8235   8136     114               1             8     68
# 3509      8163   8889     241               0             6     68
# 3510      8578   9248     245               1             1     68
# 3511      8767   8149     583               1             0     68
# 3512      8934   6904     537               0             8     68
#
#              price
# 0     6.761790e+06
# 1     9.816112e+06
# 2     8.220546e+06
# 3     8.809406e+05
# 4     8.883268e+06
# ...            ...
# 3508  5.448218e+06
# 3509  5.441036e+06
# 3510  2.797226e+06
# 3511  7.702466e+06
# 3512  4.110150e+06
#
# [3513 rows x 19 columns]

# %%
X4 = train_4[num_cols]
y4 = train_4['price']

model=XGBRegressor(max_depth=3, learning_rate=0.24 , n_estimators=3000, objective='reg:linear', booster='gbtree')
XGB=model.fit(X4,y4)

X_test = test_4[num_cols]
prediction=XGB.predict(X_test)

test_4['price'] = prediction
test_4
# Out:
# [01:38:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#          id  squareMeters  numberOfRooms  hasYard  hasPool  floors cityCode  \
# 0     22733         16354             47        1        1       9    15113
# 1     22748         35423             52        1        1      24    72385
# 2     22820         85256             74        0        1      39    50147
# 3     22826         68847             74        1        1      80    22176
# 4     22840         15815             13        1        1       7    22460
# ...     ...           ...            ...      ...      ...     ...      ...
# 2817  37020          9698             94        0        0      83    85353
# 2818  37078          4117             84        1        0      42    99430
# 2819  37135         51957             16        0        1      35    98352
# 2820  37728         75755             81        1        1      33    80837
# 2821  37818         26291             18        0        1       6    32439
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0                 6              5  2019           1                  1
# 1                 6              8  2019           1                  0
# 2                 1              1  2019           0                  1
# 3                10              6  2019           0                  1
# 4                 7              3  2019           1                  1
# ...             ...            ...   ...         ...                ...
# 2817              3              1  2021           1                  1
# 2818              8              7  2021           1                  1
# 2819              3              3  2021           0                  0
# 2820              5              7  2021           1                  0
# 2821             10              2  2021           1                  0
#
#       basement  attic  garage  hasStorageRoom  hasGuestRoom  Count  \
# 0          705   5097     122               1             5    956
# 1         8486   4375     489               1             5    956
# 2         3945   5240     745               1             0    956
# 3         9789   9476     847               1             5    956
# 4         2494   8575     827               1             5    956
# ...        ...    ...     ...             ...           ...    ...
# 2817       561   8522     293               1             9    110
# 2818      7149   9276     299               1             1    110
# 2819      5238   4333     241               0             3    110
# 2820      2341   7173     541               1             9    110
# 2821       287   8672     327               0             9    110
#
#              price
# 0     1.648989e+06
# 1     3.546444e+06
# 2     8.514914e+06
# 3     6.893146e+06
# 4     1.573644e+06
# ...            ...
# 2817  9.762145e+05
# 2818  4.370083e+05
# 2819  5.194517e+06
# 2820  7.588705e+06
# 2821  2.641181e+06
#
# [2822 rows x 19 columns]

# %%
submission = pd.concat([test_1,test_2,test_3,test_4])
submission = submission[['id','price']]
submission = submission.sort_values(by = ['id'])
submission.to_csv('submission.csv',index = False)
submission.head()
# Out:
#         id        price
# 0    22730  4758361.000
# 402  22731  6218881.000
# 827  22732  9067674.000
# 0    22733  1648989.375
# 0    22734  6761789.500
